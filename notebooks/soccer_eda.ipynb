# %%
import sys
import pathlib
source_path = pathlib.Path.cwd().resolve().parent
sys.path.append(str(source_path))

# %%
from config import *
from utils import ingest_kaggle_database
import pandas as pd

ingest_kaggle_database(SOCCER_DATABASE)

# %%
# %load_ext sql
# %sql sqlite:///../data/database.sqlite
# %config SqlMagic.style = "_deprecated_default"
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT name FROM sqlite_schema
# WHERE type = "table"
# AND name NOT LIKE "sqlite%"
# ORDER BY 1;
# Out:
#  * sqlite:///../data/database.sqlite
# Done.
# [('Country',),
#  ('League',),
#  ('Match',),
#  ('Player',),
#  ('Player_Attributes',),
#  ('Team',),
#  ('Team_Attributes',)]

# %%
#Aiden: You can start off your part by running PRAGMA table_info(name) for each of the tables

# %%
# %%sql
# PRAGMA table_info(Country)
# Out:
#  * sqlite:///../data/database.sqlite
# Done.
# [(0, 'id', 'INTEGER', 0, None, 1), (1, 'name', 'TEXT', 0, None, 0)]

# %%
# %%sql
# SELECT * FROM Country LIMIT 5;
# Out:
#  * sqlite:///../data/database.sqlite
# Done.
# [(1, 'Belgium'),
#  (1729, 'England'),
#  (4769, 'France'),
#  (7809, 'Germany'),
#  (10257, 'Italy')]
